# %%
from PIL import Image
import numpy as np
import pandas as pd
import statistics

import skimage
from skimage.io import imread, imshow
from skimage.color import rgb2gray, rgb2hsv
from skimage.measure import label, regionprops, regionprops_table
from skimage.filters import threshold_otsu
from scipy.ndimage import median_filter
from matplotlib.patches import Rectangle
from tqdm import tqdm
# Out:
# c:\users\olive\.python\lib\site-packages\skimage\io\manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper
# c:\users\olive\.python\lib\site-packages\skimage\io\manage_plugins.py:293: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   plugin_module = __import__('skimage.io._plugins.' + modname,

# %% [markdown]
# ## Preparing the Images

# %%
#Scaling down Images if needed
MAX_SIZE = (500,500)
image = Image.open('img2.jpg')
image.thumbnail(MAX_SIZE, PIL.Image.ANTIALIAS)

# %%
#isolating color channels
red,green,blue = image.split()
#getting pixel data for channels
red_val = list(red.getdata())
green_val = list(green.getdata())
blue_val = list(blue.getdata())

#calculate mode of red channel --> to determine water
red_mode_range = 0.32
green_mode_range = 1
blue_mode_range = 0.22

#getting top and bottom row of pixel values for filtering
red_top,red_bottom = red_val[:image.width], red_val[-image.width:]
green_top, green_bottom = green_val[:image.width], green_val[-image.width:]
blue_top,blue_bottom = blue_val[:image.width], blue_val[-image.width:]

#combine top and bottom row
red_filter_pixels = red_top+red_bottom
green_filter_pixels = green_top+green_bottom
blue_filter_pixels = blue_top+blue_bottom

#calculate mode for the filters
red_mode = statistics.mode(red_filter_pixels)
green_mode = statistics.mode(green_filter_pixels)
blue_mode = statistics.mode(blue_filter_pixels)

#getting range for filter
red_low, red_high = red_mode * (1-red_mode_range), red_mode * (1+red_mode_range)
green_low, green_high = green_mode * (1-green_mode_range), green_mode * (1+green_mode_range)
blue_low, blue_high = blue_mode * (1-blue_mode_range), blue_mode * (1+blue_mode_range)


#blacken out pixels if they are in red range determined to be water
pixels = image.load()
for i in range(image.width):
    for j in range(image.height):
        if pixels[i,j][0] >= red_low and pixels[i,j][0] <= red_high or pixels[i,j][2] >= blue_low and pixels[i,j][2] <= blue_high:
            pixels[i,j] = (255,255,255)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x149 at 0xF73AF40>
